# %%
import numpy as np
import scipy as sp
from scipy import special
from scipy.interpolate import CubicSpline
import astropy
from astropy.cosmology import FlatLambdaCDM
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('text', usetex = True)
from numpy import save

# %%
k = np.load('../Axion-main/k_h_fdc.npy')[:,:,:,::-1]
pk = np.load('../Axion-main/pk_h_fdc.npy')[:,:,:,::-1]

# %%
print(np.shape(k))
print(np.shape(pk))
# Out:
# (1, 25, 301, 657)
# (1, 25, 301, 657)

# %%
fv = [0.02233,0.1198,0.0001,10**-27,67.37,0.9652]
#parameter confidence intervals as given in table 3 of Planck 2015 (arxiv 1502.01589)
ci = [0.00016,0.0015,'n/a','n/a',0.66,0.0049]
#number of axioncamb runs for each parameter
runs = 25
#run values for omega_baryon
omegab = np.round(np.linspace(fv[0]-10*ci[0],fv[0]+10*ci[0],runs),5)
#run values for omega_cdm
omegac = np.round(np.linspace(fv[1]-10*ci[1],fv[1]+10*ci[1],runs),4)
#run values for omega_cdm and omega_axion used to run the desired axion fractions
fa = np.linspace(0.0001,0.025,runs)
omegaax = fv[1]*fa
omegac2 = fv[1]-omegaax
fa_zip = zip(omegac2,omegaax)
#run values for hubble constant
h0 = np.round(np.linspace(fv[4]-ci[4],fv[4]+ci[4],runs),2)
#run values for scalar tilt
ns = np.round(np.linspace(fv[5]-ci[5],fv[5]+ci[5],runs),4)
#run values for axion mass
ma = np.logspace(-29,-22,11)
params = []
params.append(omegab)
params.append(omegac)
params.append(fa)
params.append(ns)
params.append(h0)

# %%
for i in range(5):
    print(params[i])
# Out:
# [0.02073 0.02086 0.021   0.02113 0.02126 0.0214  0.02153 0.02166 0.0218
#  0.02193 0.02206 0.0222  0.02233 0.02246 0.0226  0.02273 0.02286 0.023
#  0.02313 0.02326 0.0234  0.02353 0.02366 0.0238  0.02393]
# [0.1048 0.106  0.1073 0.1086 0.1098 0.111  0.1123 0.1136 0.1148 0.116
#  0.1173 0.1186 0.1198 0.121  0.1223 0.1236 0.1248 0.126  0.1273 0.1286
#  0.1298 0.131  0.1323 0.1336 0.1348]
# [0.0001    0.0011375 0.002175  0.0032125 0.00425   0.0052875 0.006325
#  0.0073625 0.0084    0.0094375 0.010475  0.0115125 0.01255   0.0135875
#  0.014625  0.0156625 0.0167    0.0177375 0.018775  0.0198125 0.02085
#  0.0218875 0.022925  0.0239625 0.025    ]
# [0.9603 0.9607 0.9611 0.9615 0.9619 0.9623 0.9628 0.9632 0.9636 0.964
#  0.9644 0.9648 0.9652 0.9656 0.966  0.9664 0.9668 0.9672 0.9676 0.9681
#  0.9685 0.9689 0.9693 0.9697 0.9701]
# [66.71 66.77 66.82 66.88 66.93 66.99 67.04 67.1  67.15 67.21 67.26 67.32
#  67.37 67.43 67.48 67.54 67.59 67.65 67.7  67.76 67.81 67.87 67.92 67.97
#  68.03]

# %%
kval = np.load('../Axion-main/kval.npy')
# print(type(kval))
# print(kval)

# %%
print(kval[448])
# Out:
# 1.0097

# %%
print(kval[183])
print(kval[332])
# Out:
# 0.00504
# 0.099227

# %%
pk_new = np.zeros((1,301,657,25))

for j in range(25):
    pk_new[:,:,:,j] = pk[:,j,:,:]

print(np.shape(pk_new))
# Out:
# (1, 301, 657, 25)

# %%
plt.figure(figsize=(12,8))
for i in range(7):
    j = 50*i
    plt.scatter(params[4],pk_new[0][j][448],label='z=%s'%(j))
plt.xlabel('$h$',size=20)
plt.ylabel('$P(k=1)$',size=20)
plt.xlim(params[4][0],params[4][24])
plt.legend()
# plt.savefig('Omega_b')

# %%
plt.figure(figsize=(12,8))
for i in range(6):
    j = i*30+183
    plt.scatter(params[4],pk_new[0][0][j],label='k=%s'%(kval[j]))
plt.xlabel('$h$',size=20)
plt.ylabel('$P$',size=20)
plt.xlim(params[4][0],params[4][24])
plt.legend()
# plt.savefig('omegab_ks')

# %%
plt.figure(figsize=(12,8))
plt.scatter(params[4],pk_new[0][0][448])
plt.xlabel('$h$',size=20)
plt.ylabel('$P(k=1)$',size=20)
# plt.savefig('Omega_b_z0')
# Out:
# Text(0, 0.5, '$P(k=1)$')

# %%
plt.figure(figsize=(12,8))
plt.plot(params[4],np.poly1d(np.polyfit(params[4],pk_new[0][0][448],4))(params[4]))
plt.plot(params[4],pk_new[0][0][448])

# %%
Chi2 = []
for p in range(1):
    c1 = []
    for z in range(301):
        c2 = []
        for i in range(657):
            fit = np.poly1d(np.polyfit(params[3],pk_new[p][z][i],4))(params[3])
            avg = sum(fit)/len(fit)
            chi2 = sum((fit-pk_new[p][z][i])**2)/sum((fit-avg)**2)
            c2.append(chi2)
        c1.append(c2)
    Chi2.append(c1)
                
                
print(np.shape(Chi2))
# Out:
# (1, 301, 657)

# %%
plt.figure(figsize=(12,8))
for i in range(7):
    j = i*50
    plt.loglog(kval,Chi2[0][j],label='z=%s'%(j))
plt.legend()
plt.xlabel('$k$',size=20)
plt.ylabel('$\chi^2$',size=20)
# plt.savefig('Chi2_omegab')
# Out:
# Text(0, 0.5, '$\\chi^2$')

# %%
plt.figure(figsize=(12,8))
plt.loglog(kval,Chi2[0][0])
plt.xlabel('$k$',size=20)
plt.ylabel('$\chi^2$',size=20)
# plt.savefig('Chi2_omegab_z0')
# Out:
# Text(0, 0.5, '$\\chi^2$')

# %%
# print(np.polyfit(params[0],pk_new[0][0][448],4))
# print(np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4)))
# print(np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4))(params[0]))
# print(np.poly1d(np.polyder(np.polyfit(params[0],pk_new[0][0][448],4))))
# print(np.poly1d(np.polyder(np.polyfit(params[0],pk_new[0][0][448],4)))(params[0]))

# %%
k = np.load('../Axion-main/k_h_fdc.npy')[:,:,:,::-1]
pk = np.load('../Axion-main/pk_h_fdc.npy')[:,:,:,::-1]

# %%
pk_dimless = (np.power(k,3)*pk)/(2*(np.pi**2))
print(np.shape(pk_dimless))
# Out:
# (1, 25, 301, 657)

# %%
plt.loglog(k[0][12][0],pk_dimless[0][12][0])

# %%
plt.loglog(k[0][12][0],pk[0][12][0])

# %%
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-5,1e2)
plt.ylim(1e-5,1e4)
plt.scatter(k[0][12][0],pk[0][12][0])
plt.show()

# %%
print(np.poly1d(np.polyfit(np.log(k[0][12][0]),np.log(pk[0][12][0]),4)))
# print(np.poly1d(np.polyfit(np.log(k[0][12][0]),np.log(pk[0][12][0]),4))*(np.log(k[0][12][0])))
print(np.shape(np.poly1d(np.polyfit(np.log(k[0][12][0]),np.log(pk[0][12][0]),4))*(np.log(k[0][12][0]))))
# Out:
#           4           3          2
# 0.002251 x + 0.02696 x - 0.1826 x - 2.383 x + 1.494
# (661,)

# %%
logx = np.log(k[0][12][0])
logy = np.log(pk[0][12][0])
print(np.poly1d(np.polyfit(logx,logy,4)))
print(np.poly1d(np.polyfit(logx,logy,4))(logx))
# Out:
#           4           3          2
# 0.002251 x + 0.02696 x - 0.1826 x - 2.383 x + 1.494
# [-8.98074209 -8.94365631 -8.90628125 -8.86857511 -8.8305864  -8.79227002
#  -8.75367634 -8.71479142 -8.67559898 -8.63611693 -8.59636455 -8.55636257
#  -8.51605376 -8.47545548 -8.43458644 -8.39346675 -8.35207382 -8.31042724
#  -8.26850147 -8.22631536 -8.18388916 -8.1412446  -8.09830158 -8.05512989
#  -8.01169734 -7.96807923 -7.92418639 -7.88003692 -7.8356503  -7.79110909
#  -7.74625055 -7.70121877 -7.65597263 -7.61053413 -7.56485693 -7.51896088
#  -7.47286727 -7.42652363 -7.3800257  -7.33332028 -7.28642892 -7.23929184
#  -7.1920124  -7.14452971 -7.09686513 -7.04895032 -7.00098969 -6.95272896
#  -6.90437766 -6.8557643  -6.80700783 -6.75813312 -6.70905917 -6.65980646
#  -6.61050946 -6.56096898 -6.51120192 -6.46134709 -6.41130885 -6.36123444
#  -6.31089647 -6.26044214 -6.20989671 -6.15928698 -6.10835837 -6.05741109
#  -6.00632857 -5.95513398 -5.90369714 -5.85219201 -5.80064611 -5.74892304
#  -5.69721171 -5.64519845 -5.59324798 -5.54103425 -5.48875548 -5.43643838
#  -5.38391816 -5.33140933 -5.27874155 -5.22614076 -5.17322037 -5.12041972
#  -5.0673369  -5.01420779 -4.96105915 -4.9079193  -4.85457852 -4.80129766
#  -4.74785965 -4.69428315 -4.64058801 -4.58706183 -4.53336308 -4.47959228
#  -4.42577308 -4.37190147 -4.31797248 -4.26401027 -4.20997866 -4.15590079
#  -4.10180115 -4.04763992 -3.99347387 -3.93922698 -3.88499089 -3.83068599
#  -3.77637093 -3.72199718 -3.66762532 -3.61324293 -3.55883585 -3.50438811
#  -3.44992291 -3.39546481 -3.34099687 -3.28650009 -3.23199789 -3.17746949
#  -3.12298467 -3.06842875 -3.01391873 -2.95943266 -2.90489575 -2.8504318
#  -2.79591234 -2.74141135 -2.68695383 -2.6325106  -2.57804943 -2.52365046
#  -2.46922291 -2.41484832 -2.36049165 -2.30617688 -2.25186558 -2.19758058
#  -2.14334597 -2.0891196  -2.03492421 -1.98078376 -1.92672348 -1.87262406
#  -1.8186536  -1.7646139  -1.7107541  -1.65686984 -1.60298084 -1.54927151
#  -1.49552313 -1.44183916 -1.38824402 -1.33467516 -1.2812444  -1.22779671
#  -1.17444458 -1.12111841 -1.06793647 -1.01472929 -0.96161563 -0.90862034
#  -0.85566513 -0.80287783 -0.75007035 -0.69737085 -0.64469186 -0.59216776
#  -0.53970926 -0.48733847 -0.43507863 -0.38295413 -0.33086507 -0.27883133
#  -0.2268738  -0.17514692 -0.12341118 -0.07182085 -0.02026137  0.03110597
#   0.08239856  0.1335954   0.18467448  0.23576568  0.28654163  0.33744432
#   0.38798025  0.43860609  0.48897635  0.53923145  0.5895226   0.63948359
#   0.68943987  0.7391933   0.78890351  0.83855306  0.88793131  0.93720461
#   0.98635265  1.03555675  1.08439303  1.13324705  1.1818921   1.23030301
#   1.27867427  1.32698992  1.37500477  1.42292181  1.47072246  1.51836319
#   1.56587132  1.61320193  1.66040867  1.70747221  1.75437236  1.80111463
#   1.84773243  1.89415195  1.94043458  1.98656116  2.03254054  2.0783239
#   2.12397905  2.16945743  2.21476935  2.25992631  2.30490916  2.3497303
#   2.39437051  2.43887667  2.48316318  2.52731202  2.57127057  2.61505456
#   2.6586812   2.7021324   2.74538933  2.78847042  2.83135708  2.87406924
#   2.91662852  2.95897735  3.00117831  3.04313124  3.08494224  3.1265953
#   3.16798618  3.20922679  3.2503011   3.29114658  3.33183685  3.37230875
#   3.41259156  3.45266806  3.49256984  3.53228061  3.57178344  3.61111253
#   3.65019947  3.68913203  3.72778729  3.76630979  3.80463032  3.84273238
#   3.88059885  3.91832843  3.95578979  3.99308385  4.03013551  4.06698894
#   4.10369129  4.1401024   4.17633178  4.2123651   4.24818754  4.28378376
#   4.31920598  4.35437163  4.38933384  4.42407807  4.45858935  4.49292511
#   4.52699844  4.56086784  4.59459537  4.62801577  4.66118919  4.69425852
#   4.72697396  4.75955978  4.7919235   4.82405134  4.85592908  4.88754208
#   4.91904857  4.95026426  4.98126217  5.01193943  5.0425528   5.07281866
#   5.10290644  5.13280528  5.16240819  5.19179706  5.22096     5.2498848
#   5.27855894  5.30707127  5.33530932  5.36336375  5.39111909  5.41866783
#   5.44599927  5.47299342  5.49985584  5.52646725  5.55292863  5.57900369
#   5.60490692  5.63062956  5.65604486  5.68125885  5.70614183  5.73092342
#   5.75538882  5.77962455  5.80363327  5.82740529  5.8509435   5.87422534
#   5.89727967  5.92009723  5.94266861  5.96499763  5.98708847  6.00894567
#   6.03056034  6.05193736  6.07306796  6.09394326  6.11459702  6.13500683
#   6.15516422  6.17508981  6.19477565  6.21421367  6.23341071  6.2523589
#   6.27108064  6.28955334  6.30776933  6.32575178  6.34349354  6.36100306
#   6.3782577   6.39526605  6.41203708  6.42856409  6.44485646  6.46089159
#   6.47669528  6.49224503  6.50756719  6.52263939  6.53745551  6.5520426
#   6.56637839  6.58049039  6.59433979  6.60795442  6.62132895  6.63445812
#   6.64735356  6.65999345  6.67238963  6.6845541   6.69648214  6.70815231
#   6.71959373  6.7307852   6.74173919  6.75245151  6.76293473  6.77316818
#   6.7831481   6.7929038   6.80241505  6.81169466  6.82072289  6.82951269
#   6.83807678  6.84639592  6.85446729  6.86230374  6.8699177   6.87727572
#   6.88440576  6.89130498  6.89795628  6.90437216  6.91056444  6.91651668
#   6.9222272   6.9277077   6.93294334  6.93795824  6.94273774  6.94728056
#   6.95159708  6.9556745   6.95952296  6.96314114  6.96651841  6.96967366
#   6.97260498  6.97530264  6.97776685  6.98000509  6.98201656  6.98380073
#   6.98535742  6.98668676  6.98778927  6.98866864  6.98932185  6.98975176
#   6.98995801  6.98994104  6.98970241  6.98924048  6.98855676  6.98765698
#   6.98652997  6.98519103  6.98363099  6.98184966  6.9798571   6.97763507
#   6.97520558  6.97256549  6.96970595  6.9666324   6.96334695  6.95984822
#   6.95613618  6.95221515  6.94808322  6.94374021  6.93918848  6.93443086
#   6.92946429  6.92429139  6.91891527  6.91333194  6.90754423  6.90155118
#   6.89536036  6.88896667  6.88236858  6.87557439  6.86858307  6.86139305
#   6.85400225  6.8464142   6.83863293  6.8306562   6.82248819  6.81412619
#   6.80557453  6.79682996  6.78789688  6.77877144  6.76946718  6.75996162
#   6.7502778   6.74041149  6.73035748  6.72012059  6.70970619  6.69910826
#   6.68833201  6.67737034  6.66624153  6.65492489  6.64343935  6.63177675
#   6.61994281  6.60794385  6.59577036  6.58341122  6.57090627  6.55820982
#   6.54536345  6.53233665  6.51915458  6.50582488  6.49231313  6.47864624
#   6.46480895  6.4508307   6.43669605  6.42238722  6.40793546  6.39332264
#   6.37858279  6.36366928  6.34861654  6.33340318  6.31803572  6.30255301
#   6.28690024  6.27111658  6.25517642  6.23908647  6.22289066  6.2065246
#   6.19007126  6.1734234   6.15666629  6.13981045  6.12278038  6.10562547
#   6.08835471  6.07093068  6.05340823  6.03574867  6.01801078  6.0001021
#   5.9820813   5.96395798  5.94568566  5.9273291   5.90884011  5.89022638
#   5.87155922  5.85272312  5.83378903  5.81476718  5.79566847  5.77643291
#   5.75706738  5.73765465  5.71813122  5.69850579  5.67870655  5.65890376
#   5.63902888  5.61900587  5.59892983  5.57872169  5.55848211  5.53812889
#   5.51766991  5.49721461  5.47659315  5.45592586  5.43518193  5.41436049
#   5.3934716   5.37251436  5.3514874   5.33038891  5.30922905  5.28800585
#   5.26672986  5.24538558  5.22398301  5.20251882  5.18100333  5.15944747
#   5.13781799  5.11615464  5.09445366  5.07269455  5.0508873   5.02904246
#   5.00715417  4.98523309  4.96329053  4.94128381  4.9192777   4.89720943
#   4.87512671  4.85302171  4.83088553  4.80874948  4.78656282  4.76437782
#   4.74216292  4.71992843  4.69770812  4.67544468  4.653195    4.63092297
#   4.60866366  4.58637866  4.56412949  4.54185047  4.51957781  4.49732294
#   4.47506984  4.45282942  4.430584    4.4083735   4.38618018  4.36398453
#   4.34182803  4.319691    4.29758454  4.27548697  4.2534424   4.23139442
#   4.20942261  4.18746903  4.1655439   4.14365795  4.12182232  4.10001021
#   4.07827083  4.05657691  4.03493942  4.0133285   3.99179587  3.97031112
#   3.9488848   3.92752793  3.90625192  3.8850229   3.86385085  3.84274616
#   3.82176768  3.80083124  3.77994606  3.75917216  3.73852192  3.71790394
#   3.69737936  3.67695923  3.65660041  3.63636756  3.61621656  3.59621445
#   3.57625816  3.55641452  3.53669445  3.51710917  3.49760885  3.47820273
#   3.45896346  3.43977551  3.42077606  3.40184665  3.3830619   3.3644327
#   3.34597016  3.32754732  3.08598987]

# %%
plt.plot(logx,np.poly1d(np.polyfit(logx,logy,4))(logx))

# %%
plt.plot(logx,np.poly1d(np.polyder(np.polyfit(logx,logy,5)))(logx))

# %%
pk_diff = np.load('../Axion-main/diffder_h.npy')
print(np.shape(pk_diff))
# Out:
# (25, 8, 1, 550)

# %%
kval_diff = np.load('../Axion-main/kval_diff_h.npy')
print(np.shape(kval_diff))
# Out:
# (550,)

# %%
plt.figure(figsize=(12,8))
step = np.linspace(0.01,0.1,8)
for i in range(8):
    plt.plot(kval_diff, pk_diff[12][i][0],label=r'$\epsilon=%s$'%(step[i]))
    plt.xscale('log')
    plt.xlim(1e-4,1)
    plt.xlabel('$k$',fontsize=14)
    plt.ylabel('$\partial P(k)/\partial h$',fontsize=16)
    plt.title('Numerical Derivative for $\partial P(k)/\partial h$',fontsize=18)
    plt.legend()
    
plt.savefig('numder_h.pdf',bbox_inches='tight')

# %%
k_trim = np.zeros((1,25,301,550))
pk_trim = np.zeros((1,25,301,550))
dump1 = np.zeros((1,25,301,550))
dump2 = np.zeros((1,25,301,550))
for l in range(1):
    for i in range(runs):
        for y in range(301):
            c = 0
            for j in range(657):
                if j <= 15:
                    k_trim[l][i][y][j] = k[l][i][y][j]
                    pk_trim[l][i][y][j] = pk[l][i][y][j]
                    c = c+1
#                 if j>38 and j%5 == 3:
#                     dump1[l][i][y][j] = k[l][i][y][j]
#                     dump2[l][i][y][j] = pk[l][i][y][j]
                elif j>15 and j%6 != 4:
                    k_trim[l][i][y][c] = k[l][i][y][j]
                    pk_trim[l][i][y][c] = pk[l][i][y][j]
                    c = c+1

print(np.shape(k_trim))                    
print(np.shape(pk_trim))
print(c)
# Out:
# (1, 25, 301, 550)
# (1, 25, 301, 550)
# 550

# %%
derivative = np.poly1d(np.polyder(np.polyfit(k_trim[0][12][0],np.log10(pk_trim[0][12][0]),5)))(k_trim[0][12][0])*pk_trim[0][12][0]
plt.plot(k_trim[0][12][0],derivative)
plt.xscale('log')
print(np.shape(derivative))
# Out:
# (550,)

# %%
Chisq = []
for i in range(8):
    avg=sum(pk_diff[12][i][0])/len(pk_diff[12][i][0])
    Chisq.append((sum((pk_diff[12][i][0]-derivative)**2))/sum((pk_diff[12][i][0]-avg)**2))

# %%
plt.plot(step, Chisq)
plt.yscale('log')
plt.title('$h$')
plt.xlabel('$\epsilon$')
plt.ylabel('$\chi^2$')
plt.savefig('h_diff_chi2')

# %%
mergek = np.load('../Axion-main/h_mergek2.npy')
mergepk = np.load('../Axion-main/h_mergepk2.npy')

print(np.shape(mergek))
print(np.shape(mergepk))
# Out:
# (25, 16, 1, 550)
# (25, 16, 1, 550)

# %%
mergek_reshape = np.reshape(mergek,(16,1,550,25))
mergepk_reshape = np.reshape(mergepk,(16,1,550,25))

mergek_reshape2 = np.zeros((16,1,550,25))
mergepk_reshape2 = np.zeros((16,1,550,25))

for i in range(25):
    mergek_reshape2[:,:,:,i] = mergek[i,:,:,:]
    mergepk_reshape2[:,:,:,i] = mergepk[i,:,:,:]
    
print(mergek_reshape2[0][0][0])
print(mergepk_reshape2[0][0][0])
# Out:
# [0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001
#  0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001
#  0.0001 0.0001 0.0001 0.0001 0.0001]
# [333.88 334.64 335.26 335.87 336.64 337.41 338.02 338.64 339.41 340.19
#  340.81 341.43 342.2  342.98 343.6  344.38 345.01 345.79 346.41 347.04
#  347.83 348.61 349.24 350.03 350.66]

# %%
derivative = []
for i in range(550):
    der = np.poly1d(np.polyder(np.polyfit(h0,mergepk_reshape2[0][0][i],5)))(h0)
    derivative.append(der)

print(np.shape(derivative))

derivative_reshape2 = np.zeros((25,550))
for i in range(550):
    for j in range(25):
        derivative_reshape2[j][i] = derivative[i][j]

print(np.shape(derivative_reshape2))
# Out:
# (550, 25)
# (25, 550)

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    j = i*5
    plt.plot(kval_diff,pk_diff[j][0][0],label='finite difference%s'%(j))
    plt.plot(kval_diff,derivative_reshape2[j],'|',label='polyfit%s'%(j))
    plt.xscale('log')
    plt.legend(ncol=2)

plt.savefig('hderivative')

# %%
plt.figure(figsize=(12,8))
for i in range(8):
    plt.plot(kval_diff,pk_diff[12][i][0],label='finite difference%s'%(i))
    plt.plot(kval_diff,derivative_reshape2[i],'|',label='polyfit%s'%(i))
    plt.plot(kval_diff,derivative_reshape2[15-i],'|',label='polyfit%s'%(15-i))
    plt.xscale('log')
    plt.legend(ncol=2)

# %%
plt.figure(figsize=(12,8))
plt.plot(kval_diff,derivative_reshape2[8],'x',label='best polyfit by eye')
for i in range(8):
    plt.plot(kval_diff,pk_diff[8][i][0],label='finite difference')
#     plt.plot(kval_diff,derivative_reshape2[15-i],'|',label='polyfit%s'%(15-i))
    plt.xscale('log')
    plt.legend(ncol=2)
    
plt.xlabel('k')    
plt.ylabel('Pk')
plt.title('$H_0$')
# plt.savefig('hbestder')
# Out:
# Text(0.5, 1.0, '$H_0$')
