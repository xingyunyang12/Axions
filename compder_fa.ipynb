# %%
import numpy as np
import scipy as sp
from scipy import special
from scipy.interpolate import CubicSpline
import astropy
from astropy.cosmology import FlatLambdaCDM
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('text', usetex = True)
from numpy import save

# %%
k = np.load('../Axion-main/k_fa_fdc.npy')[:,:,:,::-1]
pk = np.load('../Axion-main/pk_fa_fdc.npy')[:,:,:,::-1]

# %%
print(np.shape(k))
print(np.shape(pk))
# Out:
# (1, 25, 301, 657)
# (1, 25, 301, 657)

# %%
fv = [0.02233,0.1198,0.0001,10**-27,67.37,0.9652]
#parameter confidence intervals as given in table 3 of Planck 2015 (arxiv 1502.01589)
ci = [0.00016,0.0015,'n/a','n/a',0.66,0.0049]
#number of axioncamb runs for each parameter
runs = 25
#run values for omega_baryon
omegab = np.round(np.linspace(fv[0]-10*ci[0],fv[0]+10*ci[0],runs),5)
#run values for omega_cdm
omegac = np.round(np.linspace(fv[1]-10*ci[1],fv[1]+10*ci[1],runs),4)
#run values for omega_cdm and omega_axion used to run the desired axion fractions
fa = np.linspace(0.0001,0.025,runs)
omegaax = fv[1]*fa
omegac2 = fv[1]-omegaax
fa_zip = zip(omegac2,omegaax)
#run values for hubble constant
h0 = np.round(np.linspace(fv[4]-ci[4],fv[4]+ci[4],runs),2)
#run values for scalar tilt
ns = np.round(np.linspace(fv[5]-ci[5],fv[5]+ci[5],runs),4)
#run values for axion mass
ma = np.logspace(-29,-22,11)
params = []
params.append(omegab)
params.append(omegac)
params.append(fa)
params.append(ns)
params.append(h0)

# %%
for i in range(5):
    print(params[i])
# Out:
# [0.02073 0.02086 0.021   0.02113 0.02126 0.0214  0.02153 0.02166 0.0218
#  0.02193 0.02206 0.0222  0.02233 0.02246 0.0226  0.02273 0.02286 0.023
#  0.02313 0.02326 0.0234  0.02353 0.02366 0.0238  0.02393]
# [0.1048 0.106  0.1073 0.1086 0.1098 0.111  0.1123 0.1136 0.1148 0.116
#  0.1173 0.1186 0.1198 0.121  0.1223 0.1236 0.1248 0.126  0.1273 0.1286
#  0.1298 0.131  0.1323 0.1336 0.1348]
# [0.0001    0.0011375 0.002175  0.0032125 0.00425   0.0052875 0.006325
#  0.0073625 0.0084    0.0094375 0.010475  0.0115125 0.01255   0.0135875
#  0.014625  0.0156625 0.0167    0.0177375 0.018775  0.0198125 0.02085
#  0.0218875 0.022925  0.0239625 0.025    ]
# [0.9603 0.9607 0.9611 0.9615 0.9619 0.9623 0.9628 0.9632 0.9636 0.964
#  0.9644 0.9648 0.9652 0.9656 0.966  0.9664 0.9668 0.9672 0.9676 0.9681
#  0.9685 0.9689 0.9693 0.9697 0.9701]
# [66.71 66.77 66.82 66.88 66.93 66.99 67.04 67.1  67.15 67.21 67.26 67.32
#  67.37 67.43 67.48 67.54 67.59 67.65 67.7  67.76 67.81 67.87 67.92 67.97
#  68.03]

# %%
kval = np.load('../Axion-main/kval.npy')
# print(type(kval))
# print(kval)

# %%
print(kval[448])
# Out:
# 1.0097

# %%
print(kval[183])
print(kval[332])
# Out:
# 0.00504
# 0.099227

# %%
pk_new = np.zeros((1,301,657,25))

for j in range(25):
    pk_new[:,:,:,j] = pk[:,j,:,:]

print(np.shape(pk_new))
# Out:
# (1, 301, 657, 25)

# %%
plt.figure(figsize=(12,8))
for i in range(7):
    j = 50*i
    plt.scatter(params[2],pk_new[0][j][448],label='z=%s'%(j))
plt.xlabel('$fa$',size=20)
plt.ylabel('$P(k=1)$',size=20)
plt.xlim(params[2][0],params[2][24])
plt.legend()
# plt.savefig('Omega_b')

# %%
plt.figure(figsize=(12,8))
for i in range(6):
    j = i*30+183
    plt.scatter(params[2],pk_new[0][0][j],label='k=%s'%(kval[j]))
plt.xlabel('$fa$',size=20)
plt.ylabel('$P$',size=20)
plt.xlim(params[2][0],params[2][24])
plt.legend()
# plt.savefig('omegab_ks')

# %%
plt.figure(figsize=(12,8))
plt.scatter(params[2],pk_new[0][0][448])
plt.xlabel('$fa$',size=20)
plt.ylabel('$P(k=1)$',size=20)
# plt.savefig('Omega_b_z0')
# Out:
# Text(0, 0.5, '$P(k=1)$')

# %%
plt.figure(figsize=(12,8))
plt.plot(params[2],np.poly1d(np.polyfit(params[2],pk_new[0][0][448],4))(params[2]))
plt.plot(params[2],pk_new[0][0][448])

# %%
Chi2 = []
for p in range(1):
    c1 = []
    for z in range(301):
        c2 = []
        for i in range(657):
            fit = np.poly1d(np.polyfit(params[2],pk_new[p][z][i],4))(params[2])
            avg = sum(fit)/len(fit)
            chi2 = sum((fit-pk_new[p][z][i])**2)/sum((fit-avg)**2)
            c2.append(chi2)
        c1.append(c2)
    Chi2.append(c1)
                
                
print(np.shape(Chi2))
# Out:
# (1, 301, 657)

# %%
plt.figure(figsize=(12,8))
for i in range(7):
    j = i*50
    plt.loglog(kval,Chi2[0][j],label='z=%s'%(j))
plt.legend()
plt.xlabel('$k$',size=20)
plt.ylabel('$\chi^2$',size=20)
# plt.savefig('Chi2_omegab')
# Out:
# Text(0, 0.5, '$\\chi^2$')

# %%
plt.figure(figsize=(12,8))
plt.loglog(kval,Chi2[0][0])
plt.xlabel('$k$',size=20)
plt.ylabel('$\chi^2$',size=20)
# plt.savefig('Chi2_omegab_z0')
# Out:
# Text(0, 0.5, '$\\chi^2$')

# %%
# print(np.polyfit(params[0],pk_new[0][0][448],4))
# print(np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4)))
# print(np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4))(params[0]))
# print(np.poly1d(np.polyder(np.polyfit(params[0],pk_new[0][0][448],4))))
# print(np.poly1d(np.polyder(np.polyfit(params[0],pk_new[0][0][448],4)))(params[0]))

# %%
k = np.load('../Axion-main/k_fa_fdc.npy')[:,:,:,::-1]
pk = np.load('../Axion-main/pk_fa_fdc.npy')[:,:,:,::-1]

# %%
pk_dimless = (np.power(k,3)*pk)/(2*(np.pi**2))
print(np.shape(pk_dimless))
# Out:
# (1, 25, 301, 657)

# %%
plt.loglog(k[0][12][0],pk_dimless[0][12][0])

# %%
plt.loglog(k[0][12][0],pk[0][12][0])

# %%
plt.xscale('log')
plt.yscale('log')
plt.xlim(1
#   4.55595670e+00  4.53259060e+00  4.50922165e+00  4.48581180e+00
#   4.46239776e+00  4.43893898e+00  4.41550010e+00  4.39201175e+00
#   4.36851194e+00  4.34501259e+00  4.32149664e+00  4.29797544e+00
#   4.27443012e+00  4.25090278e+00  4.22737449e+00  4.20382436e+00
#   4.18029624e+00  4.15676910e+00  4.13325452e+00  4.10972928e+00
#   4.08624016e+00  4.06272685e+00  4.03927406e+00  4.01581978e+00
#   3.99237472e+00  3.96895012e+00  3.94555775e+00  3.92216865e+00
#   3.89883542e+00  3.87552861e+00  3.85225982e+00  3.82899668e+00
#   3.80579464e+00  3.78262075e+00  3.75948616e+00  3.73640254e+00
#   3.71338205e+00  3.69038780e+00  3.66743033e+00  3.64452062e+00
#   3.62172241e+00  3.59894403e+00  3.57619513e+00  3.55354087e+00
#   3.53099462e+00  3.50845630e+00  3.48599240e+00  3.46361480e+00
#   3.44127590e+00  3.41904638e+00  3.39687754e+00  3.37484289e+00
#   3.35282861e+00  3.33090802e+00  3.30909293e+00  3.28739556e+00
#   3.26576040e+00  3.24419727e+00  3.22278666e+00  3.20139963e+00
#   3.18018875e+00  3.15902148e+00  3.13798081e+00  3.11707871e+00
#   2.79949571e+00]

# %%
plt.plot(logx,np.poly1d(np.polyfit(logx,logy,4))(logx))

# %%
plt.plot(k[0][12][0],np.poly1d(np.polyder(np.polyfit(k[0][12][0],logy,4)))(k[0][12][0])*pk[0][12][0])
plt.xscale('log')

# %%
pk_diff = np.load('../Axion-main/diffder_fa.npy')
print(np.shape(pk_diff))
# Out:
# (25, 8, 1, 554)

# %%
kval_diff = np.load('../Axion-main/kval_diff_fa.npy')
print(np.shape(kval_diff))
# Out:
# (554,)

# %%
plt.figure(figsize=(12,8))
step = np.linspace(0.1,0.3,8)
# plt.plot(k_trim[0][12][0],derivative, label='from polynomial fit')
for i in range(8):
    plt.plot(kval_diff, pk_diff[12][i][0],label=r'$\epsilon=%s$'%(step[i]))
    plt.xscale('log')
    plt.xlim(1e-4,1)
    plt.xlabel('$k$',fontsize=14)
    plt.ylabel('$\partial P(k)/\partial f_a$',fontsize=16)
    plt.title('Numerical Derivative for $\partial P(k)/\partial f_a$',fontsize=18)
    plt.legend()
    

plt.savefig('numder_fa.pdf',bbox_inches='tight')

# %%
k_trim = np.zeros((1,25,301,554))
pk_trim = np.zeros((1,25,301,554))
dump1 = np.zeros((1,25,301,554))
dump2 = np.zeros((1,25,301,554))
for l in range(1):
    for i in range(runs):
        for y in range(301):
            c = 0
            for j in range(657):
                if j <= 38:
                    k_trim[l][i][y][j] = k[l][i][y][j]
                    pk_trim[l][i][y][j] = pk[l][i][y][j]
                    c = c+1
#                 if j>38 and j%5 == 3:
#                     dump1[l][i][y][j] = k[l][i][y][j]
#                     dump2[l][i][y][j] = pk[l][i][y][j]
                elif j>38 and j%6 != 2:
                    k_trim[l][i][y][c] = k[l][i][y][j]
                    pk_trim[l][i][y][c] = pk[l][i][y][j]
                    c = c+1

print(np.shape(k_trim))                    
print(np.shape(pk_trim))
print(c)
# Out:
# (1, 25, 301, 554)
# (1, 25, 301, 554)
# 554

# %%
derivative = np.poly1d(np.polyder(np.polyfit(k_trim[0][12][0],np.log10(pk_trim[0][12][0]),5)))(k_trim[0][12][0])*pk_trim[0][12][0]
plt.plot(k_trim[0][12][0],derivative)
plt.xscale('log')
print(np.shape(derivative))
# Out:
# (554,)

# %%
Chisq = []
for i in range(8):
    avg=sum(pk_diff[12][i][0])/len(pk_diff[12][i][0])
    Chisq.append((sum((pk_diff[12][i][0]-derivative)**2))/sum((pk_diff[12][i][0]-avg)**2))

# %%
plt.plot(step, Chisq)
plt.yscale('log')
plt.title('$fa$')
plt.xlabel('$\epsilon$')
plt.ylabel('$\chi^2$')
plt.savefig('fa_diff_chi2')

# %%
mergek = np.load('../Axion-main/fa_mergek2.npy')
mergepk = np.load('../Axion-main/fa_mergepk2.npy')

print(np.shape(mergek))
print(np.shape(mergepk))
# Out:
# (25, 16, 1, 554)
# (25, 16, 1, 554)

# %%
mergek_reshape = np.reshape(mergek,(16,1,554,25))
mergepk_reshape = np.reshape(mergepk,(16,1,554,25))

mergek_reshape2 = np.zeros((16,1,554,25))
mergepk_reshape2 = np.zeros((16,1,554,25))

for i in range(25):
    mergek_reshape2[:,:,:,i] = mergek[i,:,:,:]
    mergepk_reshape2[:,:,:,i] = mergepk[i,:,:,:]
    
print(mergek_reshape2[0][0][0])
print(mergepk_reshape2[0][0][0])
# Out:
# [0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001
#  0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001
#  0.0001 0.0001 0.0001 0.0001 0.0001]
# [441.1  436.22 431.42 426.71 422.08 417.54 413.07 408.67 404.35 400.11
#  395.94 391.83 387.8  383.83 379.92 376.08 372.31 368.59 364.93 361.33
#  357.79 354.3  350.87 347.49 344.17]

# %%
derivative = []
for i in range(554):
    der = np.poly1d(np.polyder(np.polyfit(fa,mergepk_reshape2[0][0][i],5)))(fa)
    derivative.append(der)

print(np.shape(derivative))

derivative_reshape2 = np.zeros((25,554))
for i in range(554):
    for j in range(25):
        derivative_reshape2[j][i] = derivative[i][j]

print(np.shape(derivative_reshape2))
# Out:
# (554, 25)
# (25, 554)

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    j = i*5
    plt.plot(kval_diff,pk_diff[j][0][0],label='finite difference%s'%(j))
    plt.plot(kval_diff,derivative_reshape2[j],'|',label='polyfit%s'%(j))
    plt.xscale('log')
    plt.legend(ncol=2)

plt.savefig('fabderivative')

# %%
plt.figure(figsize=(12,8))
for i in range(8):
    plt.plot(kval_diff,pk_diff[12][i][0],label='finite difference%s'%(i))
    plt.plot(kval_diff,derivative_reshape2[i],'|',label='polyfit%s'%(i))
    plt.plot(kval_diff,derivative_reshape2[15-i],'|',label='polyfit%s'%(15-i))
    plt.xscale('log')
    plt.legend(ncol=2)

# %%
plt.figure(figsize=(12,8))
plt.plot(kval_diff,derivative_reshape2[15],'x',label='best polyfit by eye')
for i in range(8):
    plt.plot(kval_diff,pk_diff[24][i][0],label='finite difference')
#     plt.plot(kval_diff,derivative_reshape2[15-i],'|',label='polyfit%s'%(15-i))
    plt.xscale('log')
    plt.legend(ncol=2)
    
plt.xlabel('k')    
plt.ylabel('Pk')
plt.title('$fa$')
# plt.savefig('fabestder')
# Out:
# Text(0.5, 1.0, '$fa$')
