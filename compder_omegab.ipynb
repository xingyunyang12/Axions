# %%
import numpy as np
import scipy as sp
from scipy import special
from scipy.interpolate import CubicSpline
import astropy
from astropy.cosmology import FlatLambdaCDM
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('text', usetex = True)
from numpy import save

# %%
k = np.load('../Axion-main/k_omegab_fdc.npy')[:,:,:,::-1]
pk = np.load('../Axion-main/pk_omegab_fdc.npy')[:,:,:,::-1]

# %%
print(np.shape(k))
print(np.shape(pk))
# Out:
# (1, 25, 301, 657)
# (1, 25, 301, 657)

# %%
fv = [0.02233,0.1198,0.0001,10**-27,67.37,0.9652]
#parameter confidence intervals as given in table 3 of Planck 2015 (arxiv 1502.01589)
ci = [0.00016,0.0015,'n/a','n/a',0.66,0.0049]
#number of axioncamb runs for each parameter
runs = 25
#run values for omega_baryon
omegab = np.round(np.linspace(fv[0]-10*ci[0],fv[0]+10*ci[0],runs),5)
#run values for omega_cdm
omegac = np.round(np.linspace(fv[1]-10*ci[1],fv[1]+10*ci[1],runs),4)
#run values for omega_cdm and omega_axion used to run the desired axion fractions
fa = np.linspace(0.0001,0.025,runs)
omegaax = fv[1]*fa
omegac2 = fv[1]-omegaax
fa_zip = zip(omegac2,omegaax)
#run values for hubble constant
h0 = np.round(np.linspace(fv[4]-ci[4],fv[4]+ci[4],runs),2)
#run values for scalar tilt
ns = np.round(np.linspace(fv[5]-ci[5],fv[5]+ci[5],runs),4)
#run values for axion mass
ma = np.logspace(-29,-22,11)
params = []
params.append(omegab)
params.append(omegac)
params.append(fa)
params.append(ns)
params.append(h0)

# %%
for i in range(5):
    print(params[i])
# Out:
# [0.02073 0.02086 0.021   0.02113 0.02126 0.0214  0.02153 0.02166 0.0218
#  0.02193 0.02206 0.0222  0.02233 0.02246 0.0226  0.02273 0.02286 0.023
#  0.02313 0.02326 0.0234  0.02353 0.02366 0.0238  0.02393]
# [0.1048 0.106  0.1073 0.1086 0.1098 0.111  0.1123 0.1136 0.1148 0.116
#  0.1173 0.1186 0.1198 0.121  0.1223 0.1236 0.1248 0.126  0.1273 0.1286
#  0.1298 0.131  0.1323 0.1336 0.1348]
# [0.0001    0.0011375 0.002175  0.0032125 0.00425   0.0052875 0.006325
#  0.0073625 0.0084    0.0094375 0.010475  0.0115125 0.01255   0.0135875
#  0.014625  0.0156625 0.0167    0.0177375 0.018775  0.0198125 0.02085
#  0.0218875 0.022925  0.0239625 0.025    ]
# [0.9603 0.9607 0.9611 0.9615 0.9619 0.9623 0.9628 0.9632 0.9636 0.964
#  0.9644 0.9648 0.9652 0.9656 0.966  0.9664 0.9668 0.9672 0.9676 0.9681
#  0.9685 0.9689 0.9693 0.9697 0.9701]
# [66.71 66.77 66.82 66.88 66.93 66.99 67.04 67.1  67.15 67.21 67.26 67.32
#  67.37 67.43 67.48 67.54 67.59 67.65 67.7  67.76 67.81 67.87 67.92 67.97
#  68.03]

# %%
kval = np.load('../Axion-main/kval.npy')
# print(type(kval))
# print(kval)

# %%
print(kval[448])
# Out:
# 1.0097

# %%
print(kval[183])
print(kval[332])
# Out:
# 0.00504
# 0.099227

# %%
pk_new = np.zeros((1,301,657,25))

for j in range(25):
    pk_new[:,:,:,j] = pk[:,j,:,:]

print(np.shape(pk_new))
# Out:
# (1, 301, 657, 25)

# %%
plt.figure(figsize=(12,8))
for i in range(7):
    j = 50*i
    plt.scatter(params[0],pk_new[0][j][448],label='z=%s'%(j))
plt.xlabel('$\Omega_b$',size=20)
plt.ylabel('$P(k=1)$',size=20)
plt.xlim(params[0][0],params[0][24])
plt.legend()
# plt.savefig('Omega_b')

# %%
plt.figure(figsize=(12,8))
for i in range(6):
    j = i*30+183
    plt.scatter(params[0],pk_new[0][0][j],label='k=%s'%(kval[j]))
plt.xlabel('$\Omega_b$',size=20)
plt.ylabel('$P$',size=20)
plt.xlim(params[0][0],params[0][24])
plt.legend()
# plt.savefig('omegab_ks')

# %%
plt.figure(figsize=(12,8))
plt.scatter(params[0],pk_new[0][0][448])
plt.xlabel('$\Omega_b$',size=20)
plt.ylabel('$P(k=1)$',size=20)
# plt.savefig('Omega_b_z0')
# Out:
# Text(0, 0.5, '$P(k=1)$')

# %%
plt.figure(figsize=(12,8))
plt.plot(params[0],np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4))(params[0]))
plt.plot(params[0],pk_new[0][0][448])

# %%
Chi2 = []
for p in range(1):
    c1 = []
    for z in range(301):
        c2 = []
        for i in range(657):
            fit = np.poly1d(np.polyfit(params[p],pk_new[p][z][i],4))(params[p])
            avg = sum(fit)/len(fit)
            chi2 = sum((fit-pk_new[p][z][i])**2)/sum((fit-avg)**2)
            c2.append(chi2)
        c1.append(c2)
    Chi2.append(c1)
                
                
print(np.shape(Chi2))
# Out:
# (1, 301, 657)

# %%
plt.figure(figsize=(12,8))
for i in range(7):
    j = i*50
    plt.loglog(kval,Chi2[0][j],label='z=%s'%(j))
plt.legend()
plt.xlabel('$k$',size=20)
plt.ylabel('$\chi^2$',size=20)
# plt.savefig('Chi2_omegab')
# Out:
# Text(0, 0.5, '$\\chi^2$')

# %%
plt.figure(figsize=(12,8))
plt.loglog(kval,Chi2[0][0])
plt.xlabel('$k$',size=20)
plt.ylabel('$\chi^2$',size=20)
# plt.savefig('Chi2_omegab_z0')
# Out:
# Text(0, 0.5, '$\\chi^2$')

# %%
# print(np.polyfit(params[0],pk_new[0][0][448],4))
# print(np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4)))
# print(np.poly1d(np.polyfit(params[0],pk_new[0][0][448],4))(params[0]))
# print(np.poly1d(np.polyder(np.polyfit(params[0],pk_new[0][0][448],4))))
# print(np.poly1d(np.polyder(np.polyfit(params[0],pk_new[0][0][448],4)))(params[0]))

# %%
k = np.load('../Axion-main/k_omegab_fdc.npy')[:,:,:,::-1]
pk = np.load('../Axion-main/pk_omegab_fdc.npy')[:,:,:,::-1]

# %%
pk_dimless = (np.power(k,3)*pk)/(2*(np.pi**2))
print(np.shape(pk_dimless))
# Out:
# (1, 25, 301, 657)

# %%
plt.loglog(k[0][12][0],pk_dimless[0][12][0])

# %%
plt.loglog(k[0][12][0],pk[0][12][0])
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f87dc430ee0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:109, in install_repl_displayhook.<locals>.post_execute()
#     107 def post_execute():
#     108     if matplotlib.is_interactive():
# --> 109         draw_all()
#
# File /usr/lib/python3/dist-packages/matplotlib/_pylab_helpers.py:128, in Gcf.draw_all(cls, force)
#     126 for f_mgr in cls.get_all_fig_managers():
#     127     if force or f_mgr.canvas.figure.stale:
# --> 128         f_mgr.canvas.draw_idle()
#
# File /usr/lib/python3/dist-packages/matplotlib/backend_bases.py:1914, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1912 if not self._is_idle_drawing:
#    1913     with self._idle_draw_cntx():
# -> 1914         self.draw(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     386 self.renderer = self.get_renderer(cleared=True)
#     387 with RendererAgg.lock:
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:38, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     if artist.get_agg_filter() is not None:
#      36         renderer.start_filter()
# ---> 38     return draw(artist, renderer, *args, **kwargs)
#      39 finally:
#      40     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/figure.py:1708, in Figure.draw(self, renderer)
#    1705             # ValueError can occur when resizing a window.
#    1707     self.patch.draw(renderer)
# -> 1708     mimage._draw_list_compositing_images(
#    1709         renderer, self, artists, self.suppressComposite)
#    1711     renderer.close_group('figure')
#    1712 finally:
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:135, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133 if not_composite or not has_images:
#     134     for a in artists:
# --> 135         a.draw(renderer)
#     136 else:
#     137     # Composite any adjacent images together
#     138     image_group = []
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:38, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     if artist.get_agg_filter() is not None:
#      36         renderer.start_filter()
# ---> 38     return draw(artist, renderer, *args, **kwargs)
#      39 finally:
#      40     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2647, in _AxesBase.draw(self, renderer, inframe)
#    2644         a.draw(renderer)
#    2645     renderer.stop_rasterizing()
# -> 2647 mimage._draw_list_compositing_images(renderer, self, artists)
#    2649 renderer.close_group('axes')
#    2650 self.stale = False
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:135, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133 if not_composite or not has_images:
#     134     for a in artists:
# --> 135         a.draw(renderer)
#     136 else:
#     137     # Composite any adjacent images together
#     138     image_group = []
#
# File /usr/lib/python3/dist-packages/matplotlib/artist.py:38, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     if artist.get_agg_filter() is not None:
#      36         renderer.start_filter()
# ---> 38     return draw(artist, renderer, *args, **kwargs)
#      39 finally:
#      40     if artist.get_agg_filter() is not None:
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1204, in Axis.draw(self, renderer, *args, **kwargs)
#    1201 renderer.open_group(__name__)
#    1203 ticks_to_draw = self._update_ticks()
# -> 1204 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                         renderer)
#    1207 for tick in ticks_to_draw:
#    1208     tick.draw(renderer)
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1149, in Axis._get_tick_bboxes(self, ticks, renderer)
#    1147 def _get_tick_bboxes(self, ticks, renderer):
#    1148     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1149     return ([tick.label1.get_window_extent(renderer)
#    1150              for tick in ticks if tick.label1.get_visible()],
#    1151             [tick.label2.get_window_extent(renderer)
#    1152              for tick in ticks if tick.label2.get_visible()])
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1149, in <listcomp>(.0)
#    1147 def _get_tick_bboxes(self, ticks, renderer):
#    1148     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1149     return ([tick.label1.get_window_extent(renderer)
#    1150              for tick in ticks if tick.label1.get_visible()],
#    1151             [tick.label2.get_window_extent(renderer)
#    1152              for tick in ticks if tick.label2.get_visible()])
#
# File /usr/lib/python3/dist-packages/matplotlib/text.py:890, in Text.get_window_extent(self, renderer, dpi)
#     887 if self._renderer is None:
#     888     raise RuntimeError('Cannot get window extent w/o renderer')
# --> 890 bbox, info, descent = self._get_layout(self._renderer)
#     891 x, y = self.get_unitless_position()
#     892 x, y = self.get_transform().transform_point((x, y))
#
# File /usr/lib/python3/dist-packages/matplotlib/text.py:289, in Text._get_layout(self, renderer)
#     286 ys = []
#     288 # Full vertical extent of font, including ascenders and descenders:
# --> 289 _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     290     "lp", self._fontproperties,
#     291     ismath="TeX" if self.get_usetex() else False)
#     292 min_dy = (lp_h - lp_d) * self._linespacing
#     294 for i, line in enumerate(lines):
#
# File /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:200, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     198     texmanager = self.get_texmanager()
#     199     fontsize = prop.get_size_in_points()
# --> 200     w, h, d = texmanager.get_text_width_height_descent(
#     201         s, fontsize, renderer=self)
#     202     return w, h, d
#     204 if ismath:
#
# File /usr/lib/python3/dist-packages/matplotlib/texmanager.py:450, in TexManager.get_text_width_height_descent(self, tex, fontsize, renderer)
#     448 dvifile = self.make_dvi(tex, fontsize)
#     449 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
# --> 450     page, = dvi
#     451 # A total height (including the descent) needs to be returned.
#     452 return page.width, page.height + page.descent, page.descent
#
# File /usr/lib/python3/dist-packages/matplotlib/dviread.py:243, in Dvi.__iter__(self)
#     227 def __iter__(self):
#     228     """
#     229     Iterate through the pages of the file.
#     230
#    (...)
#     241         integers.
#     242     """
# --> 243     while self._read():
#     244         yield self._output()
#
# File /usr/lib/python3/dist-packages/matplotlib/dviread.py:301, in Dvi._read(self)
#     299 while True:
#     300     byte = self.file.read(1)[0]
# --> 301     self._dtable[byte](self, byte)
#     302     if byte == 140:                         # end of page
#     303         return True
#
# File /usr/lib/python3/dist-packages/matplotlib/dviread.py:161, in _dispatch.<locals>.decorate.<locals>.wrapper(self, byte)
#     159 if state is not None and self.state != state:
#     160     raise ValueError("state precondition failed")
# --> 161 return method(self, *[f(self, byte-min) for f in get_args])
#
# File /usr/lib/python3/dist-packages/matplotlib/dviread.py:441, in Dvi._fnt_def(self, k, c, s, d, a, l)
#     439 @_dispatch(min=243, max=246, args=('olen1', 'u4', 'u4', 'u4', 'u1', 'u1'))
#     440 def _fnt_def(self, k, c, s, d, a, l):
# --> 441     self._fnt_def_real(k, c, s, d, a, l)
#
# File /usr/lib/python3/dist-packages/matplotlib/dviread.py:446, in Dvi._fnt_def_real(self, k, c, s, d, a, l)
#     444 n = self.file.read(a + l)
#     445 fontname = n[-l:].decode('ascii')
# --> 446 tfm = _tfmfile(fontname)
#     447 if tfm is None:
#     448     raise FileNotFoundError("missing font metrics file: %s" % fontname)
#
# KeyboardInterrupt:

# %%
# plt.xscale('log')
plt.yscale('log')
# plt.xlim(1e-5,1e2)
# plt.ylim(1e-5,1e4)
plt.scatter(k[0][12][0],pk[0][12][0])
plt.show()

# %%
print(np.poly1d(np.polyfit(np.log(k[0][12][0]),np.log(pk[0][12][0]),4)))
# print(np.poly1d(np.polyfit(np.log(k[0][12][0]),np.log(pk[0][12][0]),4))*(np.log(k[0][12][0])))
print(np.shape(np.poly1d(np.polyfit(np.log(k[0][12][0]),np.log(pk[0][12][0]),4))*(np.log(k[0][12][0]))))
# Out:
#           4           3          2
# 0.002251 x + 0.02696 x - 0.1826 x - 2.383 x + 1.494
# (661,)

# %%
logx = np.log10(k[0][12][0])
logy = np.log10(pk[0][12][0])
print(np.poly1d(np.polyfit(logx,logy,4)))
print(np.poly1d(np.polyfit(logx,logy,4))(logx))
# Out:
#          4          3          2
# 0.02748 x + 0.1429 x - 0.4204 x - 2.383 x + 0.6487
# [-3.90028673 -3.88418058 -3.8679488  -3.85157323 -3.83507495 -3.81843435
#  -3.80167333 -3.78478582 -3.76776476 -3.75061793 -3.73335369 -3.71598105
#   2.95562346  2.95182575  2.94794616  2.94398303  2.93994224  2.93581403
#   2.9316084   2.92732352  2.92295712  2.91851129  2.91398837  2.90938575
#   2.90470569  2.89994509  2.89511191  2.89019716  2.88520905  2.88014405
#   2.87500463  2.86979355  2.86450667  2.85913917  2.85370833  2.84819434
#   2.84261523  2.83695776  2.83123286  2.82544385  2.81957577  2.81364031
#   2.80763085  2.80156018  2.79542158  2.78920733  2.78293101  2.77658475
#   2.77018331  2.76370645  2.75716913  2.75056205  2.74388805  2.73716399
#   2.73036608  2.72351132  2.7165886   2.70960082  2.70256707  2.69545939
#   2.68831379  2.68108372  2.6738062   2.6664858   2.65908973  2.65163945
#   2.64413886  2.63657169  2.62896179  2.62129234  2.61358887  2.60581123
#   2.5979849   2.59011404  2.58217847  2.57420632  2.56617665  2.55809281
#   2.54998577  2.54180535  2.53358239  2.5253213   2.51702684  2.50867294
#   2.5002626   2.49183175  2.48335283  2.47482962  2.46623092  2.45763067
#   2.44899912  2.44030324  2.43158433  2.42280805  2.41401811  2.40517882
#   2.3962936   2.38740997  2.37845419  2.3694785   2.36046952  2.35142688
#   2.34235496  2.33325334  2.32412145  2.31495849  2.30576888  2.29655176
#   2.28731172  2.27804201  2.26874699  2.25942522  2.25008116  2.24071957
#   2.231326    2.22191773  2.21249311  2.20304325  2.19357248  2.18408539
#   2.17457943  2.16505922  2.15552969  2.14597229  2.13641516  2.12683103
#   2.11724063  2.10764055  2.09802693  2.08841336  2.07877782  2.069143
#   2.05949519  2.04983887  2.04018871  2.03051983  2.02085691  2.01118429
#   2.0015172   1.99183894  1.98217625  1.9725006   1.9628277   1.95316253
#   1.94349814  1.93383925  1.92417818  1.91453228  1.90489385  1.8952544
#   1.88563195  1.87601797  1.86641725  1.8568204   1.84724656  1.83767125
#   1.82812901  1.81859469  1.80907273  1.79956778  1.79008469  1.78061181
#   1.77117052  1.76174897  1.75235193  1.74296642  1.73361492  1.72428421
#   1.71497888  1.70570371  1.69646365  1.68724401  1.6780491   1.66888345
#   1.65977262  1.65068004  1.64160972  1.63258773  1.62361944  1.61466516
#   1.60575145  1.5968831   1.58804138  1.57925436  1.5705029   1.56181609
#   1.55314919  1.5445312   1.53596688  1.5274611   1.51899222  1.51056425
#   1.50220874  1.49387552  1.48562417  1.47740323  1.46924512  1.46115455
#   1.45313638  1.44513544  1.34022837]

# %%
plt.plot(logx,np.poly1d(np.polyfit(logx,logy,4))(logx))

# %%
plt.plot(k[0][12][0],np.poly1d(np.polyfit(k[0][12][0],logy,15))(k[0][12][0]))

# %%
print(np.poly1d(np.polyfit(logx,logy,4)))
print(np.poly1d(np.polyder(np.polyfit(logx,logy,4))))
# Out:
#          4          3          2
# 0.02748 x + 0.1429 x - 0.4204 x - 2.383 x + 0.6487
#         3          2
# 0.1099 x + 0.4288 x - 0.8409 x - 2.383

# %%
plt.plot(logx,np.poly1d(np.polyder(np.polyfit(logx,logy,4)))(logx))

# %%
plt.plot(k[0][12][0],np.poly1d(np.polyder(np.polyfit(k[0][12][0],logy,4)))(k[0][12][0])*pk[0][12][0])
plt.xscale('log')

# %%
plt.plot(k[0][12][0],np.poly1d(np.polyder(np.polyfit(k[0][12][0],logy,5)))(k[0][12][0])*pk[0][12][0])
plt.xscale('log')

# %%
pk_diff = np.load('../Axion-main/diffder_omegab.npy')
print(np.shape(pk_diff))
# Out:
# (25, 8, 1, 554)

# %%
kval_diff = np.load('../Axion-main/kval_diff.npy')
print(np.shape(kval_diff))
# Out:
# (554,)

# %%
plt.figure(figsize=(12,8))
step = np.linspace(0.002,0.008,8)
for i in range(8):
    plt.plot(kval_diff, pk_diff[12][i][0],label='step size = %.4f' %step[i])
    plt.xscale('log')
    plt.xlim(1e-4,1)
    plt.xticks(fontsize=24)
    plt.yticks(fontsize=24)
    plt.xlabel('$k$',fontsize=30)
    plt.ylabel('$\partial P(k)/\partial \Omega_b$',fontsize=30)
    plt.title('Numerical Derivative for $\partial P(k)/\partial \Omega_b$',fontsize=36)
    plt.legend(fontsize='x-large')
    plt.savefig('numder_omegab.pdf',bbox_inches='tight')

# %%
k_trim = np.zeros((1,25,301,554))
pk_trim = np.zeros((1,25,301,554))
dump1 = np.zeros((1,25,301,554))
dump2 = np.zeros((1,25,301,554))
for l in range(1):
    for i in range(runs):
        for y in range(301):
            c = 0
            for j in range(657):
                if j <= 38:
                    k_trim[l][i][y][j] = k[l][i][y][j]
                    pk_trim[l][i][y][j] = pk[l][i][y][j]
                    c = c+1
#                 if j>38 and j%5 == 3:
#                     dump1[l][i][y][j] = k[l][i][y][j]
#                     dump2[l][i][y][j] = pk[l][i][y][j]
                elif j>38 and j%6 != 2:
                    k_trim[l][i][y][c] = k[l][i][y][j]
                    pk_trim[l][i][y][c] = pk[l][i][y][j]
                    c = c+1

k_trim = np.flip(k_trim,axis=3)
pk_trim = np.flip(pk_trim,axis=3)
print(np.shape(k_trim))                    
print(np.shape(pk_trim))
print(c)
# Out:
# (1, 25, 301, 554)
# (1, 25, 301, 554)
# 554

# %%
derivative = np.poly1d(np.polyder(np.polyfit(k_trim[0][12][0],np.log(pk_trim[0][12][0]),5)))(k_trim[0][12][0])*pk_trim[0][12][0]
plt.plot(k_trim[0][12][0],derivative)
plt.xscale('log')
print(np.shape(derivative))
# Out:
# (554,)

# %%
print(np.poly1d(np.polyder(np.polyfit(np.log(k_trim[0][12][0]),np.log(pk_trim[0][12][0]),5))))
# Out:
#            4           3           2
# -0.001251 x - 0.00295 x + 0.07398 x - 0.2617 x - 2.329

# %%
x = np.log(k_trim[0][12][0])
y = np.log(pk_trim[0][12][0])
derivative2 = np.poly1d(np.polyder(np.polyfit(x,y,5)))(k_trim[0][12][0])*(pk_trim[0][12][0])/(k_trim[0][12][0])
# derivative2 = np.poly1d(np.polyder(np.polyfit(np.log(k_trim[0][12][0]),np.log(pk_trim[0][12][0]),5)))(k_trim[0][12][0])*pk_trim[0][12][0]/k_trim[0][12][0]
plt.plot(k_trim[0][12][0],derivative2)
plt.xscale('log')
print(np.shape(derivative2))
# Out:
# (554,)

# %%
plt.figure(figsize=(12,8))
step = np.linspace(0.002,0.008,8)
plt.plot(k_trim[0][12][0],derivative, label='from polynomial fit')
for i in range(8):
    plt.plot(kval_diff, pk_diff[12][i][0],label=step[i])
    plt.xscale('log')
    plt.xlim(1e-4,1)
    plt.xlabel('$k$',fontsize=20)
    plt.ylabel('$Pk$',fontsize=20)
    plt.legend()

plt.savefig('omegab_diffcompare')

# %%
Chisq = []
for i in range(8):
    avg=sum(pk_diff[12][i][0])/len(pk_diff[12][i][0])
    Chisq.append((sum((pk_diff[12][i][0]-derivative)**2))/sum((pk_diff[12][i][0]-avg)**2))

# %%
print(np.shape(Chisq))
# Out:
# (8,)

# %%
plt.plot(step, Chisq)
plt.yscale('log')
plt.title('$\Omega_b$')
plt.xlabel('$\epsilon$')
plt.ylabel('$\chi^2$')
plt.savefig('omegab_diff_chi2')

# %%
mergek = np.load('../Axion-main/omegab_mergek2.npy')
mergepk = np.load('../Axion-main/omegab_mergepk2.npy')

print(np.shape(mergek))
print(np.shape(mergepk))
# Out:
# (25, 16, 1, 554)
# (25, 16, 1, 554)

# %%
mergek_reshape = np.reshape(mergek,(16,1,554,25))
mergepk_reshape = np.reshape(mergepk,(16,1,554,25))

mergek_reshape2 = np.zeros((16,1,554,25))
mergepk_reshape2 = np.zeros((16,1,554,25))

for i in range(25):
    mergek_reshape2[:,:,:,i] = mergek[i,:,:,:]
    mergepk_reshape2[:,:,:,i] = mergepk[i,:,:,:]
    
print(mergek_reshape2[0][0][0])
print(mergepk_reshape2[0][0][0])

# %%
derivative = []
for i in range(554):
    der = np.poly1d(np.polyder(np.polyfit(omegab,mergepk_reshape2[0][0][i],4)))(omegab)
    derivative.append(der)

print(np.shape(derivative))

derivative_reshape2 = np.zeros((25,554))
for i in range(554):
    for j in range(25):
        derivative_reshape2[j][i] = derivative[i][j]

print(np.shape(derivative_reshape2))
# Out:
# (554, 25)
# (25, 554)

# %%
print(omegab)
# Out:
# [0.02073 0.02086 0.021   0.02113 0.02126 0.0214  0.02153 0.02166 0.0218
#  0.02193 0.02206 0.0222  0.02233 0.02246 0.0226  0.02273 0.02286 0.023
#  0.02313 0.02326 0.0234  0.02353 0.02366 0.0238  0.02393]

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    j = i*5
    plt.plot(kval_diff,pk_diff[j][0][0],label='finite difference%s'%(j))
    plt.plot(kval_diff,derivative_reshape2[j],'|',label='polyfit%s'%(j))
    plt.xscale('log')
    plt.legend(ncol=2)

plt.savefig('omegabderivative')

# %%
plt.figure(figsize=(12,8))
plt.plot(kval_diff,derivative_reshape2[12],'x',label='best polyfit by eye')
for i in range(8):
    plt.plot(kval_diff,pk_diff[12][i][0],label='finite difference')
#     plt.plot(kval_diff,derivative_reshape2[15-i],'|',label='polyfit%s'%(15-i))
    plt.xscale('log')
    plt.legend(ncol=2)
    
plt.xlabel('k')    
plt.ylabel('Pk')
plt.title('$\Omega_b$')
plt.savefig('omegabbestder')
